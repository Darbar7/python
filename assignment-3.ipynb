# %% [markdown]
# How do you create a list of 3 fruits: "apple", "banana", and "cherry"?

# %%
fruits = ["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# What is the output of len(["a", "b", "c", "d"])?

# %%
len(["a", "b", "c", "d"])
# Out:
# 4

# %% [markdown]
# How do you access the first item in the list colors = ["red", "green", "blue"]?
# :

# %%
#by using slicing and indexing method
colors = ["red", "green", "blue"]
colors [:]
colors [1:3:1]
# Out:
# ['green', 'blue']

# %% [markdown]
# What does colors[1] return from colors = ["red", "green", "blue"]?

# %%
colors = ["red", "green", "blue"]
colors [1] #green color
# Out:
# 'green'

# %% [markdown]
# How do you get the last item from numbers = [10, 20, 30] using a negative index?

# %%
 #by using -1
 numbers = [10, 20, 30]
 numbers [-1]
# Out:
# 30

# %%
Use append() to add "orange" to the list fruits = ["apple", "banana"].

# %%
fruits = ["apple", "banana",('orange')]
fruits [2]
# Out:
# 'orange'

# %% [markdown]
# What does colors[1] return from colors = ["red", "green", "blue"]?

# %%
colors = ["red", "green", "blue"]
colors [1]
# Out:
# 'green'

# %% [markdown]
# Use append() to add "orange" to the list fruits = ["apple", "banana"].

# %%
fruits = ["apple", "banana"]
fruits.append('orange')
print (fruits)
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# Use insert() to add "grapes" at index 1 in the list fruits = ["apple", "banana"].

# %%
fruits = ["apple", "banana"]
fruits.insert(1, 'grapes')
print (fruits)
# Out:
# ['apple', 'grapes', 'banana']

# %% [markdown]
# Use extend() to add ["kiwi", "mango"] to the end of fruits = ["apple", "banana"].

# %%
fruits = ["apple", "banana"]
fruits.extend(["kiwi","mango"])
print (fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %% [markdown]
# Use remove() to delete "banana" from the list ["apple", "banana", "grapes"].

# %%
list = ['apples','banana','grapes']
list.remove("banana")
print(list)
# Out:
# ['apples', 'grapes']

# %% [markdown]
# Use pop() to remove the last item from the list ["a", "b", "c"]. What is the list after this?

# %%
list = ['a','b','c']
list.pop()
print(list)
# Out:
# ['a', 'b']

# %% [markdown]
# What is the output of x = ["a", "b", "c"]; x.pop(1)? What will be the new list?

# %%
x = ['a','b','c']
x.pop(1)
print(x)
# Out:
# ['a', 'c']

# %% [markdown]
# What happens if you call remove("z") on the list ["x", "y"] and "z" is not in it?

# %%
list = ["x","y"]
list.remove("z")
#there is not method to dpo this
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-324709184.py in <cell line: 0>()
#       1 list = ["x","y"]
# ----> 2 list.remove("z")
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# Use index() to find the position of "python" in the list ["java", "python", "c++"].

# %%
list = ["java","python","c++"]
list.index("c++")
# Out:
# 2

# %% [markdown]
# Use count() to count how many times "apple" appears in ["apple", "banana", "apple", "cherry"].

# %%
fruits = ["apple","banana","apple","cherry"]
fruits.count("apple")
# Out:
# 2

# %% [markdown]
# Sort the list marks = [60, 90, 70] in ascending order using sort().

# %%
marks = [60,90,70]
marks.sort()
print (marks)
# Out:
# [60, 70, 90]

# %% [markdown]
# Sort the list marks = [60, 90, 70] in descending order using sort(reverse=True).

# %%
marks =[60,90,70]
marks.sort(reverse=True)
print(marks)
# Out:
# [90, 70, 60]

# %% [markdown]
# Use reverse() to reverse the list ["a", "b", "c"].

# %%
list = ["a","b","c"]
list.reverse()
print(list)
# Out:
# ['c', 'b', 'a']

# %% [markdown]
# What is the difference between sort() and reverse()?

# %%
# sort -- it is use to arrange Accending order (low) to decending order(high)
# reverse -- it is use to reverse the list

# %% [markdown]
# Create a copy of a = [1, 2, 3] using copy() method.

# %%
a = [1,2,3]
a.copy()
print(a)
# Out:
# [1, 2, 3]

# %% [markdown]
# What is the difference between a = b and a = b.copy()?

# %%
b = [1,2,3]
a = b.copy()
print (a)
# Out:
# [1, 2, 3]

# %% [markdown]
# Use clear() to remove all items from a = [1, 2, 3].

# %%
a =[1,2,3]
a.clear()
print(a)
# Out:
# []

# %% [markdown]
# What is the result of [1, 2] + [3, 4]?

# %%
a = [1,2] + [3,4]
print("the result is =",a)
# Out:
# the result is = [1, 2, 3, 4]

# %% [markdown]
# What is the result of ["x"] * 3?

# %%
a =["x"]*3
print (a)
# Out:
# ['x', 'x', 'x']

# %% [markdown]
# Use the in keyword to check if "AI" exists in the list ["Python", "ML", "AI"].

# %%
list = ['python','ML','AI']
print("AI" in list)
# Out:
# True

# %% [markdown]
# What will "SQL" not in ["Python", "ML", "AI"] return?

# %%
list = ['python','ML''AI']
print("SQL" not in list)
# Out:
# True
