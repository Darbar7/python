# %% [markdown]
# Given the tuple colors = ('red', 'blue', 'green', 'red', 'yellow', 'red'), count how many times 'red' appears.

# %%
colors = ('red', 'blue', 'green', 'red', 'yellow', 'red')
colors.count('red')
# Out:
# 3

# %% [markdown]
# Find the index of 'green' in the tuple colors = ('red', 'blue', 'green', 'yellow').

# %%
colors = ('red', 'blue', 'green', 'yellow')
colors.index('green')
# Out:
# 2

# %% [markdown]
# Add 'cherry' to the set: fruits = {'apple', 'banana'}

# %%
fruits = {'apple','banana'}
fruits.add('cherry')
print(fruits)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# Discard 'banana' from fruits = {'apple', 'banana', 'cherry'}.

# %%
fruits = {'apple','banana','cherry'}
fruits.discard('banana')
print(fruits)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# Remove 'apple' using remove() from fruits = {'apple', 'grape'}.

# %%
fruits = {'apple', 'grape'}
fruits.remove('apple')
print(fruits)
# Out:
# {'grape'}

# %% [markdown]
# Pop any element from colors = {'red', 'green', 'blue'} and store it in a variable.

# %%
colors = {'red', 'green', 'blue'}
colors.pop()
print(colors)
# Out:
# {'green', 'red'}

# %% [markdown]
# Clear all elements from numbers = {1, 2, 3, 4}.
# :

# %%
numbers ={1,2,3,4}
numbers.clear()
print(numbers)
# Out:
# set()

# %% [markdown]
# Make a copy of the set data = {1, 2, 3} and store it in a new variable.

# %%
data ={1,2,3}
details = data.copy()
print (details)
# Out:
# {1, 2, 3}

# %% [markdown]
# Find the difference between set1 = {1, 2, 3, 4} and set2 = {3, 4, 5, 6}.

# %%
set21={1,2,3,4}
set22={3,4,5,6}
print(set21.difference(set22))
print(set21.symmetric_difference(set22))
print(set21,set22)
# Out:
# {1, 2}
# {1, 2, 5, 6}
# {1, 2, 3, 4} {3, 4, 5, 6}

# %%
set1={1,2,3,4}
set2={3,4,5,6}
set1.difference_update(set2)
# Out:
# {1, 2}

# %% [markdown]
# Find the union of a = {'x', 'y'} and b = {'y', 'z'}.

# %%
a ={'x','z'}
b ={'y','z'}
a.union(b)
# Out:
# {'x', 'y', 'z'}

# %% [markdown]
# Find common elements in set1 = {10, 20, 30} and set2 = {20, 40, 60}.

# %%
set1 = {10,20,30}
set2 = {20,40,60}
set1.symmetric_difference(set2)
# Out:
# {10, 30, 40, 60}

# %% [markdown]
# Check if {1, 2} is a subset of {1, 2, 3, 4}.

# %%
set1={1,2}
subset=(1,2,3,4)
set1.issubset(subset)
# Out:
# True

# %% [markdown]
# Check if {1, 2, 3} is a superset of {2, 3}.

# %%
seta = {1,2,3}
superset ={2,3}
seta.issuperset(superset)
# Out:
# True

# %% [markdown]
# Find elements not common in a = {1, 2, 3} and b = {3, 4, 5}.

# %%
a = {1,2,3}
b = {3,4,5}
not_common=a.symmetric_difference(b)
print("elements not common in a & b", not_common)
# Out:
# elements not common in a & b {1, 2, 4, 5}
