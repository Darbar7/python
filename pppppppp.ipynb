# %% [markdown]
# # create a tuple using employe details (id, name, salary, dept, weight)
# # check the count, len, index of all the elements
# # and get name and salary using slicing
# # get name, weight using slicing

# %%
emp =(203,'giri',3500,'ao',67)
emp.count(3500)
emp[1:3]
# Out:
# ('giri', 3500)

# %%
emp[2:5]
# Out:
# (3500, 'ao', 67)

# %%
len(emp)
# Out:
# 5

# %%
emp.index('giri')
# Out:
# 1

# %%
fruits = ['apple','banana','mango','grapes']
fruits [1:4:2]
# Out:
# ['banana', 'grapes']

# %%
num = [1,2,3,4,5]
num [3:5:1]
num [-3:-5:-1]
# Out:
# [3, 2]

# %%
name = ['ram','ravi','raju','sai','rajesh','kumar']
name [2:4:1]
name [4:6:1]
name [1:5:3]
name [-4:-6:-1]
name [-2:-7:-4]
# Out:
# ['rajesh', 'ram']

# %%
emp ={'id':123, 'namme':'raju','salary':45000,'company':'tech'}
print (empa)
# Out:
# {'id': 123, 'namme': 'raju', 'age': 45, 'marks': 234}

# %%
type (data)
# Out:
# dict

# %%
emp ['company']
# Out:
# 'tech'

# %%
emp ['id']
# Out:
# 123

# %%
emp ["city"] = 'hydrabad'
emp ['city']
# Out:
# 'hydrabad'

# %%
emp ['salary']
# Out:
# 45000

# %%
dict1 = dict(emp)

# %%
emp.update({'name':'ravi'}) , ({'age':32})
# Out:
# (None, {'age': 32})

# %%
print (emp)
# Out:
# {'id': 123, 'namme': 'ravi', 'salary': 45000, 'company': 'tech', 'city': 'hydrabad', 'name': 'ravi'}

# %%
emp.popitem ()
# Out:
# ('name', 'ravi')

# %%
emp.copy ()
# Out:
# {'id': 123,
#  'namme': 'ravi',
#  'salary': 45000,
#  'company': 'tech',
#  'city': 'hydrabad'}

# %%
emp.keys ()
# Out:
# dict_keys(['id', 'namme', 'salary', 'company', 'city'])

# %%
emp.values ()
# Out:
# dict_values([123, 'ravi', 45000, 'tech', 'hydrabad'])

# %%
emp1 =emp.copy

# %%
print (emp)
# Out:
# {'id': 123, 'namme': 'ravi', 'salary': 45000, 'company': 'tech', 'city': 'hydrabad'}

# %%
emp.items ()
# Out:
# dict_items([('id', 123), ('namme', 'ravi'), ('salary', 45000), ('company', 'tech'), ('city', 'hydrabad')])

# %%
emp.clear()

# %%
print (emp)
# Out:
# {}

# %%
details = {'rajesh':{'salary':34000,'depart':'tech'},'kumar':{'salary':35000,'depart':'mech'},'ram':{'salary':33000,'depart':'tech'}}
print (details)
# Out:
# {'rajesh': {'salary': 34000, 'depart': 'tech'}, 'kumar': {'salary': 35000, 'depart': 'mech'}, 'ram': {'salary': 33000, 'depart': 'tech'}}

# %%
for data in details.values():
  if data ['salary']  > 33000 and data['depart'] == 'tech':
    print (data)
# Out:
# {'salary': 34000, 'depart': 'tech'}

# %% [markdown]
# details = {'rajesh':{'salary':34000,'depart':'tech'},'kumar':{'salary':35000,'depart':'mech'},'ram':{'salary':33000,'depart':'tech'}}
# for data in details.values():
#   if data['salary'] > 33500 and data['depart'] == 'tech':
#     print(data)

# %% [markdown]
# # Hyderabad - bad
# # Maharastra - rastra
# # This is innomatics - innomatics
#
# T

# %%
x="kadapa"
print(x[4:6])
# Out:
# pa

# %%
v = 'rayachoti'
print(v[3:9])
# Out:
# achoti

# %%
a = "invoice_2026"
print(a[8:13])
# Out:
# 2026

# %%
b = "innomatics"
print(b[::-1])
# Out:
# scitamonni

# %%
name =" this is hydrabad  "
print (name.strip())
a = name.lstrip()
b = name.rstrip()
c = name.strip()
d = name.capitalize()
print (a)
print (c)
print (b)
len(name)
len(a)
len(b)
# Out:
# this is hydrabad
# this is hydrabad
# this is hydrabad
#  this is hydrabad
# 17

# %%
set = "word","is"
set.count("is")
"  ".join(set)
# Out:
# 'word  is'

# %%
names = "mohan,rohan"
names.endswith("an")
# Out:
# True

# %%
num = "2+1J"
print (num.isascii())
print (num.isalpha())
print (num.isdigit())
print (num.isalnum())
# Out:
# True
# False
# False
# False

# %% [markdown]
# create a code for password

# %%
password_input = input("enter the password:")

if len(password_input) >= 8 and \
   any(char.isupper() for char in password_input) and \
   any(char.islower() for char in password_input) and \
   any(char.isdigit() for char in password_input):
  print ("valid")
else:
  print ("invalid")

# %%
details = "    String true   "
a = details.strip()
b = details.lower()
# Corrected: Assuming the intent was to replace spaces with underscores.
c = details.replace(' ', '_')
print (a)
print (b)
print (c)
# Out:
# String true
#     string true
# ____String_true___

# %%
student_name = "Lucky"
branch = "mechanical"
city = "KADAPA"
sales = 1000
target = 950
print (f'student_name {student_name} branch {branch} city {city}')
print (f'{student_name} achive {sales / target * 100:.2f}')
# Out:
# student_name Lucky branch mechanical city KADAPA
# Lucky achive 105.26

# %% [markdown]
# # student marks is more than 45 then student is pass
#
# # if you have fever then take medicines

# %%
student_marks = 45
if student_marks >= 45:
  print ("he is passed")
else:
  print("he is failed")
